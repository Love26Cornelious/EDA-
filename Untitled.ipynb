# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r"C:\Users\corne\Downloads\KPMG_VI_New_raw_data_update_final.xlsx", sheet_name = 'CustomerDemographic')
# Out:
# C:\Users\corne\AppData\Local\Temp\ipykernel_19836\1031049436.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df=pd.read_excel(r"C:\Users\corne\Downloads\KPMG_VI_New_raw_data_update_final.xlsx", sheet_name = 'CustomerDemographic')

# %%
df2=pd.read_excel(r"C:\Users\corne\Downloads\KPMG_VI_New_raw_data_update_final.xlsx", sheet_name = 'Transactions')

# %%
#After importing the data we want to understand the data 


df.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
df.shape
# Out:
# (4000, 9)

# %%
df2.shape
# Out:
# (20000, 13)

# %%
df.nunique()
# Out:
# customer_id              4000
# first_name               3139
# last_name                3725
# gender                      6
# DOB                      3448
# job_industry_category       9
# wealth_segment              3
# deceased_indicator          2
# owns_car                    2
# dtype: int64

# %%
df2.nunique()
# Out:
# transaction_id             20000
# product_id                   101
# customer_id                 3494
# transaction_date             364
# online_order                   2
# order_status                   2
# brand                          6
# product_line                   4
# product_class                  3
# product_size                   3
# list_price                   296
# standard_cost                103
# product_first_sold_date      100
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            4000 non-null   int64
#  1   first_name             4000 non-null   object
#  2   last_name              3875 non-null   object
#  3   gender                 4000 non-null   object
#  4   DOB                    3913 non-null   datetime64[ns]
#  5   job_industry_category  3344 non-null   object
#  6   wealth_segment         4000 non-null   object
#  7   deceased_indicator     4000 non-null   object
#  8   owns_car               4000 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 441.5+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  datetime64[ns]
# ...

# %%
df2.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# ...

# %%
# The following step is cleaning the data 



df = df.drop_duplicates()

# %%
df2 =df2.drop_duplicates()

# %%
df.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
df= df.drop(['job_title','default','tenure'], axis=1 )

# %%
df2.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                0
# first_name                 0
# last_name                125
# gender                     0
# DOB                       87
# job_industry_category    656
# wealth_segment             0
# deceased_indicator         0
# owns_car                   0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
#Removing redundancy on the names 
df['last_name'].str.strip()
# Out:
# 0       Medendorp
# 1         Bockman
# 2          Dearle
# 3             NaN
# 4          Calton
#           ...
# 3995     Halgarth
# 3996       Nisuis
# 3997      Woolley
# 3998          NaN
# 3999      Oldland
# Name: last_name, Length: 4000, dtype: object

# %%
df['first_name'].str.strip()
# Out:
# 0              Laraine
# 1                  Eli
# 2                Arlin
# 3               Talbot
# 4       Sheila-kathryn
#              ...
# 3995           Rosalia
# 3996            Blanch
# 3997            Sarene
# 3998         Patrizius
# 3999             Kippy
# Name: first_name, Length: 4000, dtype: object

# %%
# From the DOB column we want to change its format to numbers only then format it to our own desire 
# We replace it with nothing so that we are left with numbers only 

df['DOB'].astype(str).str.replace('[^a-zA-Z0-9]', '')
# Out:
# C:\Users\corne\AppData\Local\Temp\ipykernel_19836\1997708451.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['DOB'].astype(str).str.replace('[^a-zA-Z0-9]', '')
# 0       19531012
# 1       19801216
# 2       19540120
# 3       19611003
# 4       19770513
#           ...
# 3995    19750809
# 3996    20010713
# 3997         NaT
# 3998    19731024
# 3999    19911105
# Name: DOB, Length: 4000, dtype: object

# %%
df['DOB'] = df['DOB'].astype(str).str.replace('[^a-zA-Z0-9]', '')
# Out:
# C:\Users\corne\AppData\Local\Temp\ipykernel_19836\1892509806.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['DOB'] = df['DOB'].astype(str).str.replace('[^a-zA-Z0-9]', '')

# %%
df
# Out:
#       customer_id      first_name  last_name  gender       DOB  \
# 0               1         Laraine  Medendorp       F  19531012
# 1               2             Eli    Bockman    Male  19801216
# 2               3           Arlin     Dearle    Male  19540120
# 3               4          Talbot        NaN    Male  19611003
# 4               5  Sheila-kathryn     Calton  Female  19770513
# ...           ...             ...        ...     ...       ...
# 3995         3996         Rosalia   Halgarth  Female  19750809
# 3996         3997          Blanch     Nisuis  Female  20010713
# 3997         3998          Sarene    Woolley       U       NaT
# 3998         3999       Patrizius        NaN    Male  19731024
# 3999         4000           Kippy    Oldland    Male  19911105
#
#      job_industry_category     wealth_segment deceased_indicator owns_car
# 0                   Health      Mass Customer                  N      Yes
# ...

# %%
# Letting python know what we are replacing the spaces with in the DOB


df['DOB']=df['DOB'].apply(lambda x: x[0:4] +'-'+ x[4:6] +'-'+ x[6:8])

# %%
df
# Out:
#       customer_id      first_name  last_name  gender         DOB  \
# 0               1         Laraine  Medendorp       F  1953-10-12
# 1               2             Eli    Bockman    Male  1980-12-16
# 2               3           Arlin     Dearle    Male  1954-01-20
# 3               4          Talbot        NaN    Male  1961-10-03
# 4               5  Sheila-kathryn     Calton  Female  1977-05-13
# ...           ...             ...        ...     ...         ...
# 3995         3996         Rosalia   Halgarth  Female  1975-08-09
# 3996         3997          Blanch     Nisuis  Female  2001-07-13
# 3997         3998          Sarene    Woolley       U       NaT--
# 3998         3999       Patrizius        NaN    Male  1973-10-24
# 3999         4000           Kippy    Oldland    Male  1991-11-05
#
#      job_industry_category     wealth_segment deceased_indicator owns_car
# 0                   Health      Mass Customer                  N      Yes
# ...

# %%
df['DOB'].str.replace('NaT--', '')
# Out:
# 0       1953-10-12
# 1       1980-12-16
# 2       1954-01-20
# 3       1961-10-03
# 4       1977-05-13
#            ...
# 3995    1975-08-09
# 3996    2001-07-13
# 3997
# 3998    1973-10-24
# 3999    1991-11-05
# Name: DOB, Length: 4000, dtype: object

# %%
df['DOB']=df['DOB'].str.replace('NaT--', '')

# %%
df
# Out:
#       customer_id      first_name  last_name  gender         DOB  \
# 0               1         Laraine  Medendorp       F  1953-10-12
# 1               2             Eli    Bockman    Male  1980-12-16
# 2               3           Arlin     Dearle    Male  1954-01-20
# 3               4          Talbot        NaN    Male  1961-10-03
# 4               5  Sheila-kathryn     Calton  Female  1977-05-13
# ...           ...             ...        ...     ...         ...
# 3995         3996         Rosalia   Halgarth  Female  1975-08-09
# 3996         3997          Blanch     Nisuis  Female  2001-07-13
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male  1973-10-24
# 3999         4000           Kippy    Oldland    Male  1991-11-05
#
#      job_industry_category     wealth_segment deceased_indicator owns_car
# 0                   Health      Mass Customer                  N      Yes
# ...

# %%
df['gender'].str.replace('U','')
# Out:
# 0            F
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 3995    Female
# 3996    Female
# 3997
# 3998      Male
# 3999      Male
# Name: gender, Length: 4000, dtype: object

# %%
 df['gender']=df['gender'].str.replace('M','Male')

# %%
df
# Out:
#       customer_id      first_name  last_name  gender         DOB  \
# 0               1         Laraine  Medendorp  Female  1953-10-12
# 1               2             Eli    Bockman    Male  1980-12-16
# 2               3           Arlin     Dearle    Male  1954-01-20
# 3               4          Talbot        NaN    Male  1961-10-03
# 4               5  Sheila-kathryn     Calton  Female  1977-05-13
# ...           ...             ...        ...     ...         ...
# 3995         3996         Rosalia   Halgarth  Female  1975-08-09
# 3996         3997          Blanch     Nisuis  Female  2001-07-13
# 3997         3998          Sarene    Woolley
# 3998         3999       Patrizius        NaN    Male  1973-10-24
# 3999         4000           Kippy    Oldland    Male  1991-11-05
#
#      job_industry_category     wealth_segment deceased_indicator owns_car
# 0                   Health      Mass Customer                  N      Yes
# ...

# %%
df['gender'].nunique()
# Out:
# 4

# %%
df
# Out:
#       customer_id      first_name  last_name  gender         DOB  \
# 0               1         Laraine  Medendorp  Female  1953-10-12
# 1               2             Eli    Bockman    Male  1980-12-16
# 2               3           Arlin     Dearle    Male  1954-01-20
# 3               4          Talbot        NaN    Male  1961-10-03
# 4               5  Sheila-kathryn     Calton  Female  1977-05-13
# ...           ...             ...        ...     ...         ...
# 3995         3996         Rosalia   Halgarth  Female  1975-08-09
# 3996         3997          Blanch     Nisuis  Female  2001-07-13
# 3997         3998          Sarene    Woolley
# 3998         3999       Patrizius        NaN    Male  1973-10-24
# 3999         4000           Kippy    Oldland    Male  1991-11-05
#
#      job_industry_category     wealth_segment deceased_indicator owns_car
# 0                   Health      Mass Customer                  N      Yes
# ...

# %%
# We are looking at the relationship of the two graphs

# %%
sns.pairplot(df2)

# %%
corelation = df2.corr()

# %%
sns.relplot(x= 'standard_cost', y='list_price', hue = 'gender', Data = df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19836\3054603495.py in <module>
# ----> 1 sns.relplot(x= 'standard_cost', y='list_price', hue = 'gender', Data = df2)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     945
#     946     # Use the full dataset to map the semantics
# --> 947     p = plotter(
#     948         data=data,
# ...

# %%
df2
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
# there isnt enough data for us to analyse the relationship between two databases

# %%
df.merge(df2, how= 'inner')
# Out:
#        customer_id first_name  last_name  gender         DOB  \
# 0                1    Laraine  Medendorp  Female  1953-10-12
# 1                1    Laraine  Medendorp  Female  1953-10-12
# 2                1    Laraine  Medendorp  Female  1953-10-12
# 3                1    Laraine  Medendorp  Female  1953-10-12
# 4                1    Laraine  Medendorp  Female  1953-10-12
# ...            ...        ...        ...     ...         ...
# 19992         3500       Josy    Fleeman  Female  1967-07-21
# 19993         3500       Josy    Fleeman  Female  1967-07-21
# 19994         3500       Josy    Fleeman  Female  1967-07-21
# 19995         3500       Josy    Fleeman  Female  1967-07-21
# 19996         3500       Josy    Fleeman  Female  1967-07-21
#
#       job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                    Health      Mass Customer                  N      Yes
# 1                    Health      Mass Customer                  N      Yes
# ...

# %%
df3 = df.merge(df2, how= 'inner')

# %%
df3
# Out:
#        customer_id first_name  last_name  gender         DOB  \
# 0                1    Laraine  Medendorp  Female  1953-10-12
# 1                1    Laraine  Medendorp  Female  1953-10-12
# 2                1    Laraine  Medendorp  Female  1953-10-12
# 3                1    Laraine  Medendorp  Female  1953-10-12
# 4                1    Laraine  Medendorp  Female  1953-10-12
# ...            ...        ...        ...     ...         ...
# 19992         3500       Josy    Fleeman  Female  1967-07-21
# 19993         3500       Josy    Fleeman  Female  1967-07-21
# 19994         3500       Josy    Fleeman  Female  1967-07-21
# 19995         3500       Josy    Fleeman  Female  1967-07-21
# 19996         3500       Josy    Fleeman  Female  1967-07-21
#
#       job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                    Health      Mass Customer                  N      Yes
# 1                    Health      Mass Customer                  N      Yes
# ...
